# %%
import pandas as pd
import numpy as np

# %%
dict1= { 'Name': ['Aditya','Rohan','Rahul','Dinesh','Ishita','Sakshi','Tanya','Ipsita','Ritika','Meghna'],
        'Age':[19,22,np.nan,18,np.nan,22,18,19,20,21],'Gender':['M','M','M','M','F','F','F','F','F','F'],
         'BloodGroup':['A','B','O','AB','A','A','B','AB','B','AB'],'Interest':['CSE','CSE','IT','ECE','EEE','IT','CSE','IT','IT','IT']}

# %%
dict1
# Out:
# {'Name': ['Aditya',
#   'Rohan',
#   'Rahul',
#   'Dinesh',
#   'Ishita',
#   'Sakshi',
#   'Tanya',
#   'Ipsita',
#   'Ritika',
#   'Meghna'],
#  'Age': [19, 22, nan, 18, nan, 22, 18, 19, 20, 21],
#  'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'F', 'F'],
#  'BloodGroup': ['A', 'B', 'O', 'AB', 'A', 'A', 'B', 'AB', 'B', 'AB'],
#  'Interest': ['CSE', 'CSE', 'IT', 'ECE', 'EEE', 'IT', 'CSE', 'IT', 'IT', 'IT']}

# %%
df=pd.DataFrame(dict1)

# %%
df#TASK 1
# Out:
#      Name   Age Gender BloodGroup Interest
# 0  Aditya  19.0      M          A      CSE
# 1   Rohan  22.0      M          B      CSE
# 2   Rahul   NaN      M          O       IT
# 3  Dinesh  18.0      M         AB      ECE
# 4  Ishita   NaN      F          A      EEE
# 5  Sakshi  22.0      F          A       IT
# 6   Tanya  18.0      F          B      CSE
# 7  Ipsita  19.0      F         AB       IT
# 8  Ritika  20.0      F          B       IT
# 9  Meghna  21.0      F         AB       IT

# %%
df.info()#TASK 2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        10 non-null     object
#  1   Age         8 non-null      float64
#  2   Gender      10 non-null     object
#  3   BloodGroup  10 non-null     object
#  4   Interest    10 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 528.0+ bytes

# %%
df.describe()# TASK 3
# Out:
#              Age
# count   8.000000
# mean   19.875000
# std     1.642081
# min    18.000000
# 25%    18.750000
# 50%    19.500000
# 75%    21.250000
# max    22.000000

# %%
df.loc[4] #TASK 4
# Out:
# Name          Ishita
# Age              NaN
# Gender             F
# BloodGroup         A
# Interest         EEE
# Name: 4, dtype: object

# %%
df.isnull().sum()#TASK 5
# Out:
# Name          0
# Age           2
# Gender        0
# BloodGroup    0
# Interest      0
# dtype: int64
